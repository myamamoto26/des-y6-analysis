# %%
import pickle
import numpy as np
import fitsio as fio
import matplotlib
from matplotlib import pyplot as plt

# %%
with open('/global/cfs/cdirs/des/mgatti/BFD_CAT_v1.0.2_6_01_23.pkl', 'rb') as f:
    d_bfd = pickle.load(f)

# %%
d_bfd
# Out:
# {'e1': array([ 0.18895894, -0.40726765, -0.40747889, ..., -0.14649106,
#          0.01661652,  0.1949477 ]),
#  'e2': array([-0.09226831, -0.35019499,  0.33313675, ..., -0.19226663,
#         -0.20859686, -0.43671977]),
#  'NUNIQUE': array([600, 368, 600, ...,  51, 200, 200], dtype=int32),
#  'COADD_OBJECT_ID': array([910823034, 910823033, 910823029, ..., 909007892, 909007884,
#         909007883]),
#  'R00': array([ -6.8932714,  79.333374 ,  -7.166485 , ..., -16.853912 ,
#          -3.939855 , -11.582911 ], dtype=float32),
#  'R11': array([-35.14044  ,  56.79189  , -23.138268 , ..., -22.096428 ,
#          -4.3941817, -16.44447  ], dtype=float32),
#  'R01': array([ -9.41132  ,  16.434622 , -38.67188  , ...,  -1.5247687,
#           0.3652474,  -0.4195633], dtype=float32),
#  'fluxes_riz': array([[ 1887.7567,  1640.2509,  4972.178 ],
#         [40501.746 , 62223.465 , 75443.68  ],
#         [ 1421.2869,  4054.7666, 10120.49  ],
#         ...,
# ...
